# %%
# defining variable in Python

myVar = 25
print(myVar)
# Out:
# 25

# %%
# know more about the variable - type

print(type(myVar))
a = 'Shweta'
b = 3.8
c = [1,'h',4.5]
print(a , b)
print('a is',type(a))
print('b is',type(b))
print('c is',type(c))
# Out:
# <class 'int'>
# Shweta 3.8
# a is <class 'str'>
# b is <class 'float'>
# c is <class 'list'>

# %%
# Arithmetic with variables

d = ((myVar + 10) * 2)/5
print(d)
print(type(d))
# Out:
# 14.0
# <class 'float'>

# %%
# Some conversions with pyhton variable
# int to its hexadecimal value

e = print('Hexadecimal of 25 = ',hex(myVar))

# getting the unique value of the variable using the id()
print(id(myVar))

# converting the id into hexadecimal
print(hex(140730822830624))
print(hex(id(myVar)))

# type of variable
print(type(e))
# Out:
# Hexadecimal of 25 =  0x19
# 140730822830624
# 0x7ffe72b42a20
# 0x7ffe72b42a20
# <class 'NoneType'>

# %%
# working with Strings with the string type variable 'a' is defined above

name = a +' '+'Gupta'
print(name)
# 1. Length of the variable or string using len()- a = 'shweta'

print('length of a = ',len(a))
f = 'I am foodie'
print(f,'\nlength of f = ',len(f))
# Out:
# Shweta Gupta
# length of a =  6
# I am foodie
# length of f =  11

# %%
# 2. Indexing - 
#left to right (returns x to (y-1) values)

print(f[2:6])

# last letter

print(f[-3])
print(f[-2])
print(f[-1])
# Out:
# am f
# d
# i
# e

# %%
# know more about the data types - str, int, float, decimal

help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
# flow of control ----> if-else statements

var1 = 5
var2 = 8

if (var1 > var2):
    print("Var1 is greater")
elif var1 == var2:
    print("both are equal")
elif var1 < var2:
    print("var2 is greater")
# Out:
# var2 is greater
