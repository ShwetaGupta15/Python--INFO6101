# %%
import urllib.request
import re

# %%
mypage = urllib.request.urlopen("http://www.microstrategy.com/us/company/contact-us")
myPageData = str(mypage.read())
print(myPageData)
# Out:
# b'\r\n<!DOCTYPE HTML>\r\n<html lang="en">\r\n    <head>\n    <meta charset="UTF-8"/>\n    <title>About Us</title>\n    \n    <meta name="description" content="We provide powerful data analytics and visualization solutions to empower individuals and companies with actionable intelligence."/>\n    <meta name="template" content="interior-page"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <!--  Open graph tags -->\r\n<meta property="og:image" content="https://www.microstrategy.com/content/dam/website-assets/website-images/hero-banners/generic/coworkers-with-dashboards-on-devices-1.jpg"/>\n<meta property="og:type" content="website"/>\n<meta property="og:site_name" content="MicroStrategy"/>\n<meta property="og:title" content="About Us"/>\n<meta property="fb:page_id" content="18991493475"/>\n<meta property="og:url" content="https://www.microstrategy.com/en/company"/>\n<meta property="og:description" content="We provide powerful data analytics and visuali
# ...

# %%
emailList = re.findall(">(\w*\S*\w*@\w*\.\w+)",myPageData)
print(emailList)
# Out:
# ['info@microstrategy.com', 'support@microstrategy.com']
